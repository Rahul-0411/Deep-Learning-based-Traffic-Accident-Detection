# %%
import cv2
import numpy as np
import math
import os
from ultralytics import YOLO
from tensorflow.keras.models import load_model


ACCIDENT_VIDEOS_DIR = r"F:\a"
NONACCIDENT_VIDEOS_DIR = r"F:\New folder"
OUTPUT_DATASET_DIR = r"F:\output"

ACCIDENT_OUTPUT_DIR = os.path.join(OUTPUT_DATASET_DIR, 'accident')
NONACCIDENT_OUTPUT_DIR = os.path.join(OUTPUT_DATASET_DIR, 'nonaccident')
os.makedirs(ACCIDENT_OUTPUT_DIR, exist_ok=True)
os.makedirs(NONACCIDENT_OUTPUT_DIR, exist_ok=True)


FRAME_SKIP = 4


yolo_model = YOLO("yolov5l.pt")
vehicle_classes = ["car", "truck", "bus", "motorcycle"]


def are_boxes_close(box1, box2, image_width, image_height, rel_distance_threshold=0.05):

    x1, y1, x2, y2 = box1
    x1b, y1b, x2b, y2b = box2

    
    center1 = ((x1 + x2) / 2, (y1 + y2) / 2)
    center2 = ((x1b + x2b) / 2, (y1b + y2b) / 2)

    
    w1, h1 = x2 - x1, y2 - y1
    w2, h2 = x2b - x1b, y2b - y1b

    
    if (x1 < x2b and x2 > x1b and y1 < y2b and y2 > y1b):
        return True, 0

    
    distance = math.sqrt((center1[0] - center2[0])**2 + (center1[1] - center2[1])**2)
    avg_size = (w1 + h1 + w2 + h2) / 4
    normalized_distance = distance / avg_size

    return normalized_distance < 2.0, normalized_distance

def combine_boxes(boxes, padding=0.1):
    
    x1 = min(b[0] for b in boxes)
    y1 = min(b[1] for b in boxes)
    x2 = max(b[2] for b in boxes)
    y2 = max(b[3] for b in boxes)
    
    width, height = x2 - x1, y2 - y1
    pad_x, pad_y = int(width * padding), int(height * padding)
    
    return (max(0, x1 - pad_x), max(0, y1 - pad_y),
            x2 + pad_x, y2 + pad_y)

def expand_roi_to_square(x1, y1, x2, y2, image_width, image_height):
    
    width = x2 - x1
    height = y2 - y1
    
    if width > height:
        diff = width - height
        new_y1 = max(0, y1 - diff // 2)
        new_y2 = y2 + diff - (y1 - new_y1)
        if new_y2 > image_height:
            new_y2 = image_height
            new_y1 = max(0, new_y2 - width)
        new_x1, new_x2 = x1, x2
    elif height > width:
        diff = height - width
        new_x1 = max(0, x1 - diff // 2)
        new_x2 = x2 + diff - (x1 - new_x1)
        if new_x2 > image_width:
            new_x2 = image_width
            new_x1 = max(0, new_x2 - height)
        new_y1, new_y2 = y1, y2
    else:
        new_x1, new_y1, new_x2, new_y2 = x1, y1, x2, y2
    
    return new_x1, new_y1, new_x2, new_y2


def process_video(video_path, output_folder, label):
 
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Could not open video: {video_path}")
        return

    frame_count = 0
    roi_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        if frame_count % FRAME_SKIP != 0:
            continue

        height, width, _ = frame.shape
        frame_clean = frame.copy()

        
        results = yolo_model(frame)

        
        vehicle_boxes = []
        for result in results:
            for box in result.boxes:
                class_id = int(box.cls[0])
                confidence = float(box.conf[0])
                class_name = yolo_model.names[class_id]
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                if class_name in vehicle_classes and confidence > 0.5:
                    vehicle_boxes.append((x1, y1, x2, y2, class_name, confidence))

        
        processed_vehicles = set()
        accident_rois = []
        for i, box1 in enumerate(vehicle_boxes):
            if i in processed_vehicles:
                continue
            x1, y1, x2, y2, class_name1, conf1 = box1
            close_boxes = [box1[:4]]
            processed_vehicles.add(i)

            for j, box2 in enumerate(vehicle_boxes[i+1:], start=i+1):
                if j in processed_vehicles:
                    continue
                is_close, _ = are_boxes_close(box1[:4], box2[:4], width, height)
                if is_close:
                    close_boxes.append(box2[:4])
                    processed_vehicles.add(j)

            if len(close_boxes) > 1:
                combined_roi = combine_boxes(close_boxes, padding=0.15)
                accident_rois.append(combined_roi)

        
        for roi in accident_rois:
            x1, y1, x2, y2 = roi
            
            new_x1, new_y1, new_x2, new_y2 = expand_roi_to_square(x1, y1, x2, y2, width, height)
            
            square_roi = frame_clean[new_y1:new_y2, new_x1:new_x2]
            
            resized_roi = cv2.resize(square_roi, (224, 224))
            
            roi_count += 1
            output_path = os.path.join(output_folder, f"{label}_frame{frame_count:04d}_roi{roi_count:03d}.jpg")
            cv2.imwrite(output_path, resized_roi)
            print(f"Saved {label} ROI: {output_path}")

    cap.release()
    print(f"Finished processing video: {video_path}")


def process_all_videos():
    
    for filename in os.listdir(ACCIDENT_VIDEOS_DIR):
        if filename.lower().endswith(('.mp4', '.avi', '.mov')):
            video_path = os.path.join(ACCIDENT_VIDEOS_DIR, filename)
            process_video(video_path, ACCIDENT_OUTPUT_DIR, "accident")
    
    
    for filename in os.listdir(NONACCIDENT_VIDEOS_DIR):
        if filename.lower().endswith(('.mp4', '.avi', '.mov')):
            video_path = os.path.join(NONACCIDENT_VIDEOS_DIR, filename)
            process_video(video_path, NONACCIDENT_OUTPUT_DIR, "nonaccident")


process_all_videos()
# Out:
# PRO TIP  Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
#
# 0: 384x640 3 cars, 531.2ms
# Speed: 11.0ms preprocess, 531.2ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0004_roi001.jpg
#
# 0: 384x640 3 cars, 393.5ms
# Speed: 4.0ms preprocess, 393.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 362.6ms
# Speed: 3.0ms preprocess, 362.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 335.4ms
# Speed: 3.0ms preprocess, 335.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0016_roi002.jpg
#
# 0: 384x640 3 cars, 446.1ms
# Speed: 6.0ms preprocess, 446.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0020_roi003.jpg
#
# 0: 384x640 3 cars, 381.5ms
# Speed: 3.0ms preprocess, 381.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0024_roi004.jpg
#
# 0: 384x640 4 cars, 332.9ms
# Speed: 2.0ms preprocess, 332.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0028_roi005.jpg
#
# 0: 384x640 3 cars, 373.7ms
# Speed: 3.0ms preprocess, 373.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 343.8ms
# Speed: 3.0ms preprocess, 343.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 340.3ms
# Speed: 3.0ms preprocess, 340.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0040_roi006.jpg
#
# 0: 384x640 4 cars, 1 bench, 341.2ms
# Speed: 2.0ms preprocess, 341.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0044_roi007.jpg
#
# 0: 384x640 4 cars, 1 bench, 352.2ms
# Speed: 2.0ms preprocess, 352.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0048_roi008.jpg
#
# 0: 384x640 4 cars, 348.4ms
# Speed: 3.0ms preprocess, 348.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 344.6ms
# Speed: 2.0ms preprocess, 344.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 344.8ms
# Speed: 3.0ms preprocess, 344.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame
3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0340_roi050.jpg
# Saved accident ROI: F:\output\accident\accident_frame0340_roi051.jpg
#
# 0: 384x640 8 cars, 1 truck, 409.3ms
# Speed: 2.0ms preprocess, 409.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0344_roi052.jpg
# Saved accident ROI: F:\output\accident\accident_frame0344_roi053.jpg
#
# 0: 384x640 7 cars, 1 truck, 409.2ms
# Speed: 3.0ms preprocess, 409.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0348_roi054.jpg
#
# 0: 384x640 7 cars, 1 truck, 378.2ms
# Speed: 3.0ms preprocess, 378.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 347.1ms
# Speed: 2.0ms preprocess, 347.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0356_roi055.jpg
#
# 0: 384x640 6 cars, 1 truck, 393.9ms
# Speed: 3.0ms preprocess, 393.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0360_roi056.jpg
# Saved accident ROI: F:\output\accident\accident_frame0360_roi057.jpg
#
# 0: 384x640 7 cars, 2 trucks, 1 traffic light, 339.5ms
# Speed: 2.0ms preprocess, 339.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0364_roi058.jpg
# Saved accident ROI: F:\output\accident\accident_frame0364_roi059.jpg
#
# 0: 384x640 6 cars, 1 truck, 1 traffic light, 361.8ms
# Speed: 2.0ms preprocess, 361.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0368_roi060.jpg
# Saved accident ROI: F:\output\accident\accident_frame0368_roi061.jpg
#
# 0: 384x640 6 cars, 1 truck, 1 traffic light, 489.1ms
# Speed: 3.0ms preprocess, 489.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0372_roi062.jpg
# Saved accident ROI: F:\output\accident\accident_frame0372_roi063.jpg
#
# 0: 384x640 8 cars, 1 truck, 405.2ms
# Speed: 3.0ms preprocess, 405.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0376_roi064.jpg
# Saved accident ROI: F:\output\accident\accident_frame0376_roi065.jpg
#
# 0: 384x640 7 cars, 359.7ms
# Speed: 3.0ms preprocess, 359.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0380_roi066.jpg
# Saved accident ROI: F:\output\accident\accident_frame0380_roi067.jpg
#
# 0: 384x640 8 cars, 1 truck, 366.3ms
# Speed: 3.0ms preprocess, 366.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0384_roi068.jpg
# Saved accident ROI: F:\output\accident\accident_frame0384_roi069.jpg
#
# 0: 384x640 7 cars, 365.2ms
# Speed: 4.0ms preprocess, 365.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0388_roi070.jpg
# Saved accident ROI: F:\output\accident\accident_frame0388_roi071.jpg
#
# 0: 384x640 7 cars, 1 truck, 336.2ms
# Speed: 2.0ms preprocess, 336.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0392_roi072.jpg
#
# 0: 384x640 9 cars, 1 truck, 345.2ms
# Speed: 3.0ms preprocess, 345.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0396_roi073.jpg
#
# 0: 384x640 9 cars, 1 truck, 331.2ms
# Speed: 2.0ms preprocess, 331.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0400_roi074.jpg
# Saved accident ROI: F:\output\accident\accident_frame0400_roi075.jpg
#
# 0: 384x640 8 cars, 1 truck, 357.3ms
# Speed: 2.0ms preprocess, 357.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0404_roi076.jpg
# Saved accident ROI: F:\output\accident\accident_frame0404_roi077.jpg
# Saved accident ROI: F:\output\accident\accident_frame0404_roi078.jpg
#
# 0: 384x640 9 cars, 1 truck, 1 traffic light, 343.6ms
# Speed: 3.0ms preprocess, 343.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0408_roi079.jpg
# Saved accident ROI: F:\output\accident\accident_frame0408_roi080.jpg
# Saved accident ROI: F:\output\accident\accident_frame0408_roi081.jpg
#
# 0: 384x640 9 cars, 1 truck, 1 traffic light, 333.8ms
# Speed: 2.0ms preprocess, 333.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0412_roi082.jpg
# Saved accident ROI: F:\output\accident\accident_frame0412_roi083.jpg
# Saved accident ROI: F:\output\accident\accident_frame0412_roi084.jpg
#
# 0: 384x640 9 cars, 1 truck, 348.4ms
# Speed: 3.0ms preprocess, 348.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0416_roi085.jpg
# Saved accident ROI: F:\output\accident\accident_frame0416_roi086.jpg
# Saved accident ROI: F:\output\accident\accident_frame0416_roi087.jpg
#
# 0: 384x640 9 cars, 1 truck, 472.9ms
# Speed: 6.0ms preprocess, 472.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0420_roi088.jpg
# Saved accident ROI: F:\output\accident\accident_frame0420_roi089.jpg
# Saved accident ROI: F:\output\accident\accident_frame0420_roi090.jpg
#
# 0: 384x640 8 cars, 1 truck, 532.3ms
# Speed: 4.0ms preprocess, 532.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0424_roi091.jpg
# Saved accident ROI: F:\output\accident\accident_frame0424_roi092.jpg
# Saved accident ROI: F:\output\accident\accident_frame0424_roi093.jpg
#
# 0: 384x640 9 cars, 1 truck, 489.8ms
# Speed: 4.0ms preprocess, 489.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0428_roi094.jpg
# Saved accident ROI: F:\output\accident\accident_frame0428_roi095.jpg
# Saved accident ROI: F:\output\accident\accident_frame0428_roi096.jpg
#
# 0: 384x640 9 cars, 1 truck, 410.9ms
# Speed: 4.0ms preprocess, 410.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0432_roi097.jpg
# Saved accident ROI: F:\output\accident\accident_frame0432_roi098.jpg
# Saved accident ROI: F:\output\accident\accident_frame0432_roi099.jpg
#
# 0: 384x640 9 cars, 1 truck, 406.1ms
# Speed: 3.0ms preprocess, 406.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0436_roi100.jpg
# Saved accident ROI: F:\output\accident\accident_frame0436_roi101.jpg
# Saved accident ROI: F:\output\accident\accident_frame0436_roi102.jpg
#
# 0: 384x640 8 cars, 1 truck, 398.1ms
# Speed: 2.0ms preprocess, 398.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0440_roi103.jpg
# Saved accident ROI: F:\output\accident\accident_frame0440_roi104.jpg
#
# 0: 384x640 9 cars, 1 truck, 478.8ms
# Speed: 4.0ms preprocess, 478.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0444_roi105.jpg
# Saved accident ROI: F:\output\accident\accident_frame0444_roi106.jpg
# Saved accident ROI: F:\output\accident\accident_frame0444_roi107.jpg
#
# 0: 384x640 10 cars, 1 truck, 559.9ms
# Speed: 6.1ms preprocess, 559.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0448_roi108.jpg
# Saved accident ROI: F:\output\accident\accident_frame0448_roi109.jpg
#
# 0: 384x640 11 cars, 1 truck, 428.3ms
# Speed: 3.0ms preprocess, 428.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0452_roi110.jpg
# Saved accident ROI: F:\output\accident\accident_frame0452_roi111.jpg
#
# 0: 384x640 9 cars, 405.8ms
# Speed: 2.0ms preprocess, 405.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0456_roi112.jpg
# Saved accident ROI: F:\output\accident\accident_frame0456_roi113.jpg
#
# 0: 384x640 8 cars, 398.7ms
# Speed: 3.5ms preprocess, 398.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0460_roi114.jpg
# Saved accident ROI: F:\output\accident\accident_frame0460_roi115.jpg
#
# 0: 384x640 9 cars, 1 traffic light, 394.4ms
# Speed: 3.0ms preprocess, 394.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0464_roi116.jpg
# Saved accident ROI: F:\output\accident\accident_frame0464_roi117.jpg
#
# 0: 384x640 8 cars, 1 truck, 1 traffic light, 404.1ms
# Speed: 2.0ms preprocess, 404.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0468_roi118.jpg
# Saved accident ROI: F:\output\accident\accident_frame0468_roi119.jpg
#
# 0: 384x640 8 cars, 416.5ms
# Speed: 3.0ms preprocess, 416.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0472_roi120.jpg
# Saved accident ROI: F:\output\accident\accident_frame0472_roi121.jpg
#
# 0: 384x640 9 cars, 392.2ms
# Speed: 3.0ms preprocess, 392.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0476_roi122.jpg
# Saved accident ROI: F:\output\accident\accident_frame0476_roi123.jpg
#
# 0: 384x640 6 cars, 1 truck, 354.2ms
# Speed: 3.0ms preprocess, 354.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0480_roi124.jpg
#
# 0: 384x640 8 cars, 345.1ms
# Speed: 2.0ms preprocess, 345.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0484_roi125.jpg
#
# 0: 384x640 8 cars, 343.8ms
# Speed: 3.0ms preprocess, 343.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0488_roi126.jpg
# Saved accident ROI: F:\output\accident\accident_frame0488_roi127.jpg
#
# 0: 384x640 1 person, 9 cars, 334.1ms
# Speed: 3.0ms preprocess, 334.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0492_roi128.jpg
# Saved accident ROI: F:\output\accident\accident_frame0492_roi129.jpg
# Saved accident ROI: F:\output\accident\accident_frame0492_roi130.jpg
#
# 0: 384x640 9 cars, 405.9ms
# Speed: 3.0ms preprocess, 405.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0496_roi131.jpg
# Saved accident ROI: F:\output\accident\accident_frame0496_roi132.jpg
# Saved accident ROI: F:\output\accident\accident_frame0496_roi133.jpg
#
# 0: 384x640 9 cars, 1 truck, 351.9ms
# Speed: 2.0ms preprocess, 351.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0500_roi134.jpg
# Saved accident ROI: F:\output\accident\accident_frame0500_roi135.jpg
#
# 0: 384x640 10 cars, 345.2ms
# Speed: 2.0ms preprocess, 345.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0504_roi136.jpg
# Saved accident ROI: F:\output\accident\accident_frame0504_roi137.jpg
# Saved accident ROI: F:\output\accident\accident_frame0504_roi138.jpg
#
# 0: 384x640 8 cars, 1 truck, 348.1ms
# Speed: 2.0ms preprocess, 348.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0508_roi139.jpg
# Saved accident ROI: F:\output\accident\accident_frame0508_roi140.jpg
#
# 0: 384x640 8 cars, 1 truck, 345.6ms
# Speed: 3.0ms preprocess, 345.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0512_roi141.jpg
# Saved accident ROI: F:\output\accident\accident_frame0512_roi142.jpg
#
# 0: 384x640 8 cars, 1 truck, 348.7ms
# Speed: 2.0ms preprocess, 348.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0516_roi143.jpg
# Saved accident ROI: F:\output\accident\accident_frame0516_roi144.jpg
#
# 0: 384x640 9 cars, 484.0ms
# Speed: 4.0ms preprocess, 484.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0520_roi145.jpg
# Saved accident ROI: F:\output\accident\accident_frame0520_roi146.jpg
#
# 0: 384x640 10 cars, 1 traffic light, 427.9ms
# Speed: 3.0ms preprocess, 427.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0524_roi147.jpg
# Saved accident ROI: F:\output\accident\accident_frame0524_roi148.jpg
#
# 0: 384x640 9 cars, 401.2ms
# Speed: 3.0ms preprocess, 401.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0528_roi149.jpg
# Saved accident ROI: F:\output\accident\accident_frame0528_roi150.jpg
#
# 0: 384x640 8 cars, 345.4ms
# Speed: 2.0ms preprocess, 345.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0532_roi151.jpg
# Saved accident ROI: F:\output\accident\accident_frame0532_roi152.jpg
#
# 0: 384x640 8 cars, 347.2ms
# Speed: 2.0ms preprocess, 347.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0536_roi153.jpg
# Saved accident ROI: F:\output\accident\accident_frame0536_roi154.jpg
#
# 0: 384x640 11 cars, 1 traffic light, 480.1ms
# Speed: 4.0ms preprocess, 480.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0540_roi155.jpg
# Saved accident ROI: F:\output\accident\accident_frame0540_roi156.jpg
#
# 0: 384x640 11 cars, 1 truck, 372.7ms
# Speed: 3.0ms preprocess, 372.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0544_roi157.jpg
# Saved accident ROI: F:\output\accident\accident_frame0544_roi158.jpg
# Saved accident ROI: F:\output\accident\accident_frame0544_roi159.jpg
#
# 0: 384x640 11 cars, 346.6ms
# Speed: 2.0ms preprocess, 346.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0548_roi160.jpg
# Saved accident ROI: F:\output\accident\accident_frame0548_roi161.jpg
# Saved accident ROI: F:\output\accident\accident_frame0548_roi162.jpg
#
# 0: 384x640 8 cars, 343.6ms
# Speed: 3.0ms preprocess, 343.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0552_roi163.jpg
# Saved accident ROI: F:\output\accident\accident_frame0552_roi164.jpg
# Saved accident ROI: F:\output\accident\accident_frame0552_roi165.jpg
#
# 0: 384x640 9 cars, 339.6ms
# Speed: 3.0ms preprocess, 339.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0556_roi166.jpg
# Saved accident ROI: F:\output\accident\accident_frame0556_roi167.jpg
# Saved accident ROI: F:\output\accident\accident_frame0556_roi168.jpg
#
# 0: 384x640 11 cars, 345.1ms
# Speed: 3.0ms preprocess, 345.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0560_roi169.jpg
# Saved accident ROI: F:\output\accident\accident_frame0560_roi170.jpg
#
# 0: 384x640 9 cars, 463.3ms
# Speed: 4.2ms preprocess, 463.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0564_roi171.jpg
# Saved accident ROI: F:\output\accident\accident_frame0564_roi172.jpg
# Saved accident ROI: F:\output\accident\accident_frame0564_roi173.jpg
#
# 0: 384x640 7 cars, 1 traffic light, 428.3ms
# Speed: 3.0ms preprocess, 428.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0568_roi174.jpg
# Saved accident ROI: F:\output\accident\accident_frame0568_roi175.jpg
# Saved accident ROI: F:\output\accident\accident_frame0568_roi176.jpg
#
# 0: 384x640 7 cars, 1 traffic light, 375.7ms
# Speed: 3.0ms preprocess, 375.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0572_roi177.jpg
# Saved accident ROI: F:\output\accident\accident_frame0572_roi178.jpg
# Saved accident ROI: F:\output\accident\accident_frame0572_roi179.jpg
#
# 0: 384x640 8 cars, 1 traffic light, 355.2ms
# Speed: 2.0ms preprocess, 355.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0576_roi180.jpg
# Saved accident ROI: F:\output\accident\accident_frame0576_roi181.jpg
# Saved accident ROI: F:\output\accident\accident_frame0576_roi182.jpg
#
# 0: 384x640 8 cars, 1 traffic light, 345.1ms
# Speed: 2.0ms preprocess, 345.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0580_roi183.jpg
# Saved accident ROI: F:\output\accident\accident_frame0580_roi184.jpg
#
# 0: 384x640 8 cars, 1 traffic light, 330.8ms
# Speed: 2.0ms preprocess, 330.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0584_roi185.jpg
# Saved accident ROI: F:\output\accident\accident_frame0584_roi186.jpg
#
# 0: 384x640 7 cars, 1 traffic light, 340.7ms
# Speed: 2.0ms preprocess, 340.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0588_roi187.jpg
# Saved accident ROI: F:\output\accident\accident_frame0588_roi188.jpg
#
# 0: 384x640 7 cars, 1 traffic light, 346.6ms
# Speed: 2.0ms preprocess, 346.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0592_roi189.jpg
# Saved accident ROI: F:\output\accident\accident_frame0592_roi190.jpg
#
# 0: 384x640 8 cars, 359.1ms
# Speed: 2.0ms preprocess, 359.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0596_roi191.jpg
# Saved accident ROI: F:\output\accident\accident_frame0596_roi192.jpg
#
# 0: 384x640 8 cars, 349.2ms
# Speed: 2.0ms preprocess, 349.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0600_roi193.jpg
#
# 0: 384x640 7 cars, 348.1ms
# Speed: 4.0ms preprocess, 348.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0604_roi194.jpg
# Saved accident ROI: F:\output\accident\accident_frame0604_roi195.jpg
#
# 0: 384x640 6 cars, 1 traffic light, 351.9ms
# Speed: 4.0ms preprocess, 351.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0608_roi196.jpg
# Saved accident ROI: F:\output\accident\accident_frame0608_roi197.jpg
#
# 0: 384x640 7 cars, 1 traffic light, 349.3ms
# Speed: 2.0ms preprocess, 349.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0612_roi198.jpg
# Saved accident ROI: F:\output\accident\accident_frame0612_roi199.jpg
#
# 0: 384x640 7 cars, 343.2ms
# Speed: 2.0ms preprocess, 343.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0616_roi200.jpg
# Saved accident ROI: F:\output\accident\accident_frame0616_roi201.jpg
#
# 0: 384x640 7 cars, 344.7ms
# Speed: 3.0ms preprocess, 344.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0620_roi202.jpg
# Saved accident ROI: F:\output\accident\accident_frame0620_roi203.jpg
#
# 0: 384x640 6 cars, 1 truck, 340.9ms
# Speed: 2.0ms preprocess, 340.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0624_roi204.jpg
# Saved accident ROI: F:\output\accident\accident_frame0624_roi205.jpg
#
# 0: 384x640 5 cars, 1 truck, 342.2ms
# Speed: 2.0ms preprocess, 342.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0628_roi206.jpg
# Saved accident ROI: F:\output\accident\accident_frame0628_roi207.jpg
#
# 0: 384x640 5 cars, 2 trucks, 348.7ms
# Speed: 2.0ms preprocess, 348.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0632_roi208.jpg
# Saved accident ROI: F:\output\accident\accident_frame0632_roi209.jpg
#
# 0: 384x640 6 cars, 1 truck, 348.9ms
# Speed: 3.0ms preprocess, 348.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0636_roi210.jpg
#
# 0: 384x640 6 cars, 1 truck, 350.8ms
# Speed: 12.0ms preprocess, 350.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0640_roi211.jpg
#
# 0: 384x640 7 cars, 342.5ms
# Speed: 3.0ms preprocess, 342.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0644_roi212.jpg
#
# 0: 384x640 5 cars, 1 truck, 346.5ms
# Speed: 2.0ms preprocess, 346.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0648_roi213.jpg
#
# 0: 384x640 7 cars, 1 truck, 1 traffic light, 350.6ms
# Speed: 2.0ms preprocess, 350.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0652_roi214.jpg
#
# 0: 384x640 7 cars, 1 traffic light, 350.6ms
# Speed: 2.0ms preprocess, 350.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0656_roi215.jpg
#
# 0: 384x640 8 cars, 1 traffic light, 345.1ms
# Speed: 3.0ms preprocess, 345.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0660_roi216.jpg
#
# 0: 384x640 8 cars, 1 traffic light, 343.3ms
# Speed: 3.0ms preprocess, 343.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0664_roi217.jpg
# Saved accident ROI: F:\output\accident\accident_frame0664_roi218.jpg
#
# 0: 384x640 8 cars, 354.2ms
# Speed: 3.0ms preprocess, 354.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0668_roi219.jpg
# Saved accident ROI: F:\output\accident\accident_frame0668_roi220.jpg
#
# 0: 384x640 7 cars, 354.3ms
# Speed: 2.0ms preprocess, 354.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0672_roi221.jpg
# Saved accident ROI: F:\output\accident\accident_frame0672_roi222.jpg
#
# 0: 384x640 7 cars, 1 traffic light, 343.2ms
# Speed: 3.0ms preprocess, 343.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0676_roi223.jpg
# Saved accident ROI: F:\output\accident\accident_frame0676_roi224.jpg
#
# 0: 384x640 11 cars, 1 truck, 343.2ms
# Speed: 2.0ms preprocess, 343.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0680_roi225.jpg
# Saved accident ROI: F:\output\accident\accident_frame0680_roi226.jpg
#
# 0: 384x640 8 cars, 351.7ms
# Speed: 3.0ms preprocess, 351.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0684_roi227.jpg
# Saved accident ROI: F:\output\accident\accident_frame0684_roi228.jpg
#
# 0: 384x640 9 cars, 1 truck, 345.8ms
# Speed: 2.0ms preprocess, 345.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0688_roi229.jpg
# Saved accident ROI: F:\output\accident\accident_frame0688_roi230.jpg
#
# 0: 384x640 9 cars, 353.1ms
# Speed: 2.0ms preprocess, 353.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0692_roi231.jpg
# Saved accident ROI: F:\output\accident\accident_frame0692_roi232.jpg
# Saved accident ROI: F:\output\accident\accident_frame0692_roi233.jpg
#
# 0: 384x640 9 cars, 353.4ms
# Speed: 4.0ms preprocess, 353.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0696_roi234.jpg
# Saved accident ROI: F:\output\accident\accident_frame0696_roi235.jpg
# Saved accident ROI: F:\output\accident\accident_frame0696_roi236.jpg
#
# 0: 384x640 9 cars, 1 truck, 352.3ms
# Speed: 2.0ms preprocess, 352.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0700_roi237.jpg
# Saved accident ROI: F:\output\accident\accident_frame0700_roi238.jpg
#
# 0: 384x640 9 cars, 348.7ms
# Speed: 2.0ms preprocess, 348.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved accident ROI: F:\output\accident\accident_frame0704_roi239.jpg
# Saved accident ROI: F:\output\accident\accident_frame0704_roi240.jpg
# Saved accident ROI: F:\output\accident\accident_frame0704_roi241.jpg
# Finished processing video: F:\a\video028 - Made with Clipchamp.mp4
#
# 0: 384x640 13 cars, 1 bus, 3 trucks, 370.6ms
# Speed: 3.0ms preprocess, 370.6ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0004_roi001.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0004_roi002.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0004_roi003.jpg
#
# 0: 384x640 12 cars, 1 bus, 2 trucks, 342.9ms
# Speed: 3.0ms preprocess, 342.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0008_roi004.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0008_roi005.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0008_roi006.jpg
#
# 0: 384x640 12 cars, 1 bus, 2 trucks, 473.1ms
# Speed: 3.0ms preprocess, 473.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0012_roi007.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0012_roi008.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0012_roi009.jpg
#
# 0: 384x640 13 cars, 1 bus, 2 trucks, 491.9ms
# Speed: 3.0ms preprocess, 491.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0016_roi010.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0016_roi011.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0016_roi012.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0016_roi013.jpg
#
# 0: 384x640 13 cars, 1 bus, 2 trucks, 423.4ms
# Speed: 3.0ms preprocess, 423.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0020_roi014.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0020_roi015.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0020_roi016.jpg
#
# 0: 384x640 14 cars, 1 bus, 2 trucks, 399.5ms
# Speed: 3.0ms preprocess, 399.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0024_roi017.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0024_roi018.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0024_roi019.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0024_roi020.jpg
#
# 0: 384x640 14 cars, 1 bus, 2 trucks, 411.8ms
# Speed: 3.0ms preprocess, 411.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0028_roi021.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0028_roi022.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0028_roi023.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0028_roi024.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0028_roi025.jpg
#
# 0: 384x640 15 cars, 1 bus, 2 trucks, 397.9ms
# Speed: 3.0ms preprocess, 397.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0032_roi026.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0032_roi027.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0032_roi028.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0032_ro
jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0120_roi141.jpg
#
# 0: 384x640 18 cars, 1 bus, 4 trucks, 383.6ms

# %%
import cv2
import numpy as np
import math
import os
from ultralytics import YOLO
from tensorflow.keras.models import load_model


ACCIDENT_VIDEOS_DIR = r"F:\pratice_dataset\practise_accident_video"
NONACCIDENT_VIDEOS_DIR = r"F:\pratice_dataset\pratice_nono_accident_video"
OUTPUT_DATASET_DIR = r"F:\output"

ACCIDENT_OUTPUT_DIR = os.path.join(OUTPUT_DATASET_DIR, 'accident')
NONACCIDENT_OUTPUT_DIR = os.path.join(OUTPUT_DATASET_DIR, 'nonaccident')
os.makedirs(ACCIDENT_OUTPUT_DIR, exist_ok=True)
os.makedirs(NONACCIDENT_OUTPUT_DIR, exist_ok=True)


FRAME_SKIP = 4


yolo_model = YOLO("yolov5l.pt")
vehicle_classes = ["car", "truck", "bus", "motorcycle"]


def are_boxes_close(box1, box2, image_width, image_height, rel_distance_threshold=0.05):

    x1, y1, x2, y2 = box1
    x1b, y1b, x2b, y2b = box2

    
    center1 = ((x1 + x2) / 2, (y1 + y2) / 2)
    center2 = ((x1b + x2b) / 2, (y1b + y2b) / 2)

    
    w1, h1 = x2 - x1, y2 - y1
    w2, h2 = x2b - x1b, y2b - y1b

    
    if (x1 < x2b and x2 > x1b and y1 < y2b and y2 > y1b):
        return True, 0

    
    distance = math.sqrt((center1[0] - center2[0])**2 + (center1[1] - center2[1])**2)
    avg_size = (w1 + h1 + w2 + h2) / 4
    normalized_distance = distance / avg_size

    return normalized_distance < 2.0, normalized_distance

def combine_boxes(boxes, padding=0.1):
    
    x1 = min(b[0] for b in boxes)
    y1 = min(b[1] for b in boxes)
    x2 = max(b[2] for b in boxes)
    y2 = max(b[3] for b in boxes)
    
    width, height = x2 - x1, y2 - y1
    pad_x, pad_y = int(width * padding), int(height * padding)
    
    return (max(0, x1 - pad_x), max(0, y1 - pad_y),
            x2 + pad_x, y2 + pad_y)


def extract_fixed_size_roi(x1, y1, x2, y2, image_width, image_height, output_size=224):
    # Compute the center of the combined ROI
    center_x = int((x1 + x2) / 2)
    center_y = int((y1 + y2) / 2)
    
    half_size = output_size // 2
    new_x1 = center_x - half_size
    new_y1 = center_y - half_size
    new_x2 = center_x + half_size
    new_y2 = center_y + half_size

    # Adjust coordinates if they go beyond image boundaries
    if new_x1 < 0:
        new_x1 = 0
        new_x2 = output_size
    if new_y1 < 0:
        new_y1 = 0
        new_y2 = output_size
    if new_x2 > image_width:
        new_x2 = image_width
        new_x1 = image_width - output_size
    if new_y2 > image_height:
        new_y2 = image_height
        new_y1 = image_height - output_size
    
    # Final check to make sure the ROI is the correct size
    # (Note: When near the image edges, the ROI might be less than output_size,
    # adjust as needed or warn)
    return new_x1, new_y1, new_x2, new_y2

def process_video(video_path, output_folder, label):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Could not open video: {video_path}")
        return

    frame_count = 0
    roi_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        if frame_count % FRAME_SKIP != 0:
            continue

        height, width, _ = frame.shape
        frame_clean = frame.copy()

        # Run YOLO detection on the frame
        results = yolo_model(frame)

        vehicle_boxes = []
        for result in results:
            for box in result.boxes:
                class_id = int(box.cls[0])
                confidence = float(box.conf[0])
                class_name = yolo_model.names[class_id]
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                if class_name in vehicle_classes and confidence > 0.5:
                    vehicle_boxes.append((x1, y1, x2, y2, class_name, confidence))

        processed_vehicles = set()
        accident_rois = []
        for i, box1 in enumerate(vehicle_boxes):
            if i in processed_vehicles:
                continue
            x1, y1, x2, y2, class_name1, conf1 = box1
            close_boxes = [box1[:4]]
            processed_vehicles.add(i)

            for j, box2 in enumerate(vehicle_boxes[i+1:], start=i+1):
                if j in processed_vehicles:
                    continue
                is_close, _ = are_boxes_close(box1[:4], box2[:4], width, height)
                if is_close:
                    close_boxes.append(box2[:4])
                    processed_vehicles.add(j)

            if len(close_boxes) > 1:
                combined_roi = combine_boxes(close_boxes, padding=0.15)
                accident_rois.append(combined_roi)

        for roi in accident_rois:
            x1, y1, x2, y2 = roi

            # Instead of expanding to square and resizing, extract a 224x224 patch directly.
            new_x1, new_y1, new_x2, new_y2 = extract_fixed_size_roi(x1, y1, x2, y2, width, height, output_size=224)

            fixed_roi = frame_clean[new_y1:new_y2, new_x1:new_x2]
            
            # No cv2.resize here; fixed_roi will already be 224x224 (provided the image is large enough)
            roi_count += 1
            output_path = os.path.join(output_folder, f"{label}_frame{frame_count:04d}_roi{roi_count:03d}.jpg")
            cv2.imwrite(output_path, fixed_roi)
            print(f"Saved {label} ROI: {output_path}")

    cap.release()
    print(f"Finished processing video: {video_path}")

def process_all_videos():
    for filename in os.listdir(ACCIDENT_VIDEOS_DIR):
        if filename.lower().endswith(('.mp4', '.avi', '.mov')):
            video_path = os.path.join(ACCIDENT_VIDEOS_DIR, filename)
            process_video(video_path, ACCIDENT_OUTPUT_DIR, "accident")

    for filename in os.listdir(NONACCIDENT_VIDEOS_DIR):
        if filename.lower().endswith(('.mp4', '.avi', '.mov')):
            video_path = os.path.join(NONACCIDENT_VIDEOS_DIR, filename)
            process_video(video_path, NONACCIDENT_OUTPUT_DIR, "nonaccident")

process_all_videos()
# Out:
# PRO TIP  Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov5lu.pt to 'yolov5lu.pt'...
# 100%|████████████████████████████████████████████████████████████████████████████████| 102M/102M [02:05<00:00, 849kB/s]
# 0: 512x640 8 cars, 2 trucks, 5 traffic lights, 663.7ms
# Speed: 14.5ms preprocess, 663.7ms inference, 22.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0004_roi001.jpg
# Saved accident ROI: F:\output\accident\accident_frame0004_roi002.jpg
# Saved accident ROI: F:\output\accident\accident_frame0004_roi003.jpg
#
# 0: 512x640 7 cars, 2 trucks, 5 traffic lights, 520.1ms
# Speed: 3.0ms preprocess, 520.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0008_roi004.jpg
# Saved accident ROI: F:\output\accident\accident_frame0008_roi005.jpg
# Saved accident ROI: F:\output\accident\accident_frame0008_roi006.jpg
#
# 0: 512x640 7 cars, 2 trucks, 5 traffic lights, 664.8ms
# Speed: 7.0ms preprocess, 664.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0012_roi007.jpg
# Saved accident ROI: F:\output\accident\accident_frame0012_roi008.jpg
# Saved accident ROI: F:\output\accident\accident_frame0012_roi009.jpg
#
# 0: 512x640 9 cars, 1 truck, 5 traffic lights, 723.2ms
# Speed: 7.0ms preprocess, 723.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0016_roi010.jpg
# Saved accident ROI: F:\output\accident\accident_frame0016_roi011.jpg
#
# 0: 512x640 8 cars, 1 truck, 4 traffic lights, 517.2ms
# Speed: 3.0ms preprocess, 517.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0020_roi012.jpg
# Saved accident ROI: F:\output\accident\accident_frame0020_roi013.jpg
# Saved accident ROI: F:\output\accident\accident_frame0020_roi014.jpg
#
# 0: 512x640 10 cars, 1 truck, 4 traffic lights, 517.9ms
# Speed: 3.0ms preprocess, 517.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0024_roi015.jpg
# Saved accident ROI: F:\output\accident\accident_frame0024_roi016.jpg
# Saved accident ROI: F:\output\accident\accident_frame0024_roi017.jpg
#
# 0: 512x640 8 cars, 1 truck, 4 traffic lights, 520.3ms
# Speed: 3.0ms preprocess, 520.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0028_roi018.jpg
# Saved accident ROI: F:\output\accident\accident_frame0028_roi019.jpg
#
# 0: 512x640 9 cars, 1 truck, 4 traffic lights, 527.2ms
# Speed: 4.0ms preprocess, 527.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0032_roi020.jpg
# Saved accident ROI: F:\output\accident\accident_frame0032_roi021.jpg
#
# 0: 512x640 9 cars, 1 truck, 4 traffic lights, 523.2ms
# Speed: 3.0ms preprocess, 523.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0036_roi022.jpg
# Saved accident ROI: F:\output\accident\accident_frame0036_roi023.jpg
#
# 0: 512x640 7 cars, 2 trucks, 4 traffic lights, 655.5ms
# Speed: 7.0ms preprocess, 655.5ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0040_roi024.jpg
# Saved accident ROI: F:\output\accident\accident_frame0040_roi025.jpg
#
# 0: 512x640 8 cars, 1 truck, 4 traffic lights, 519.9ms
# Speed: 3.0ms preprocess, 519.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0044_roi026.jpg
# Saved accident ROI: F:\output\accident\accident_frame0044_roi027.jpg
# Saved accident ROI: F:\output\accident\accident_frame0044_roi028.jpg
#
# 0: 512x640 7 cars, 1 bus, 1 truck, 4 traffic lights, 519.9ms
# Speed: 3.0ms preprocess, 519.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0048_roi029.jpg
# Saved accident ROI: F:\output\accident\accident_frame0048_roi030.jpg
# Saved accident ROI: F:\output\accident\accident_frame0048_roi031.jpg
#
# 0: 512x640 10 cars, 1 bus, 1 truck, 4 traffic lights, 533.0ms
# Speed: 3.0ms preprocess, 533.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0052_roi032.jpg
# Saved accident ROI: F:\output\accident\accident_frame0052_roi033.jpg
# Saved accident ROI: F:\output\accident\accident_frame0052_roi034.jpg
#
# 0: 512x640 9 cars, 1 bus, 1 truck, 4 traffic lights, 518.8ms
# Speed: 3.0ms preprocess, 518.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0056_roi035.jpg
# Saved accident ROI: F:\output\accident\accident_frame0056_roi036.jpg
# Saved accident ROI: F:\output\accident\accident_frame0056_roi037.jpg
# Saved accident ROI: F:\output\accident\accident_frame0056_roi038.jpg
#
# 0: 512x640 10 cars, 1 bus, 2 traffic lights, 532.8ms
# Speed: 3.0ms preprocess, 532.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0060_roi039.jpg
# Saved accident ROI: F:\output\accident\accident_frame0060_roi040.jpg
# Saved accident ROI: F:\output\accident\accident_frame0060_roi041.jpg
# Saved accident ROI: F:\output\accident\accident_frame0060_roi042.jpg
#
# 0: 512x640 9 cars, 1 truck, 4 traffic lights, 512.7ms
# Speed: 3.0ms preprocess, 512.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0064_roi043.jpg
# Saved accident ROI: F:\output\accident\accident_frame0064_roi044.jpg
# Saved accident ROI: F:\output\accident\accident_frame0064_roi045.jpg
# Saved accident ROI: F:\output\accident\accident_frame0064_roi046.jpg
#
# 0: 512x640 10 cars, 1 truck, 5 traffic lights, 451.9ms
# Speed: 3.0ms preprocess, 451.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0068_roi047.jpg
# Saved accident ROI: F:\output\accident\accident_frame0068_roi048.jpg
# Saved accident ROI: F:\output\accident\accident_frame0068_roi049.jpg
# Saved accident ROI: F:\output\accident\accident_frame0068_roi050.jpg
#
# 0: 512x640 9 cars, 1 bus, 1 truck, 4 traffic lights, 470.5ms
# Speed: 2.0ms preprocess, 470.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0072_roi051.jpg
# Saved accident ROI: F:\output\accident\accident_frame0072_roi052.jpg
#
# 0: 512x640 8 cars, 1 bus, 2 trucks, 4 traffic lights, 456.8ms
# Speed: 3.0ms preprocess, 456.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0076_roi053.jpg
# Saved accident ROI: F:\output\accident\accident_frame0076_roi054.jpg
#
# 0: 512x640 10 cars, 2 trucks, 4 traffic lights, 462.7ms
# Speed: 2.0ms preprocess, 462.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0080_roi055.jpg
# Saved accident ROI: F:\output\accident\accident_frame0080_roi056.jpg
#
# 0: 512x640 10 cars, 2 trucks, 4 traffic lights, 458.0ms
# Speed: 2.0ms preprocess, 458.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0084_roi057.jpg
# Saved accident ROI: F:\output\accident\accident_frame0084_roi058.jpg
#
# 0: 512x640 10 cars, 1 truck, 4 traffic lights, 485.6ms
# Speed: 2.0ms preprocess, 485.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0088_roi059.jpg
# Saved accident ROI: F:\output\accident\accident_frame0088_roi060.jpg
#
# 0: 512x640 10 cars, 1 bus, 3 trucks, 4 traffic lights, 476.3ms
# Speed: 2.0ms preprocess, 476.3ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0092_roi061.jpg
# Saved accident ROI: F:\output\accident\accident_frame0092_roi062.jpg
#
# 0: 512x640 10 cars, 3 trucks, 3 traffic lights, 460.7ms
# Speed: 2.0ms preprocess, 460.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0096_roi063.jpg
# Saved accident ROI: F:\output\accident\accident_frame0096_roi064.jpg
#
# 0: 512x640 9 cars, 3 trucks, 2 traffic lights, 446.4ms
# Speed: 3.0ms preprocess, 446.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0100_roi065.jpg
# Saved accident ROI: F:\output\accident\accident_frame0100_roi066.jpg
#
# 0: 512x640 12 cars, 4 trucks, 2 traffic lights, 450.3ms
# Speed: 2.0ms preprocess, 450.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0104_roi067.jpg
# Saved accident ROI: F:\output\accident\accident_frame0104_roi068.jpg
#
# 0: 512x640 11 cars, 3 trucks, 2 traffic lights, 454.9ms
# Speed: 3.0ms preprocess, 454.9ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0108_roi069.jpg
# Saved accident ROI: F:\output\accident\accident_frame0108_roi070.jpg
#
# 0: 512x640 11 cars, 4 trucks, 2 traffic lights, 452.0ms
# Speed: 2.0ms preprocess, 452.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0112_roi071.jpg
# Saved accident ROI: F:\output\accident\accident_frame0112_roi072.jpg
#
# 0: 512x640 11 cars, 3 trucks, 2 traffic lights, 450.8ms
# Speed: 3.0ms preprocess, 450.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0116_roi073.jpg
# Saved accident ROI: F:\output\accident\accident_frame0116_roi074.jpg
#
# 0: 512x640 11 cars, 2 trucks, 4 traffic lights, 451.6ms
# Speed: 2.0ms preprocess, 451.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0120_roi075.jpg
# Saved accident ROI: F:\output\accident\accident_frame0120_roi076.jpg
#
# 0: 512x640 9 cars, 4 trucks, 3 traffic lights, 460.3ms
# Speed: 2.0ms preprocess, 460.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0124_roi077.jpg
# Saved accident ROI: F:\output\accident\accident_frame0124_roi078.jpg
#
# 0: 512x640 10 cars, 2 trucks, 3 traffic lights, 459.5ms
# Speed: 2.0ms preprocess, 459.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0128_roi079.jpg
# Saved accident ROI: F:\output\accident\accident_frame0128_roi080.jpg
#
# 0: 512x640 6 cars, 2 trucks, 3 traffic lights, 448.0ms
# Speed: 2.0ms preprocess, 448.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0132_roi081.jpg
# Saved accident ROI: F:\output\accident\accident_frame0132_roi082.jpg
#
# 0: 512x640 9 cars, 2 trucks, 3 traffic lights, 473.0ms
# Speed: 2.0ms preprocess, 473.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0136_roi083.jpg
# Saved accident ROI: F:\output\accident\accident_frame0136_roi084.jpg
#
# 0: 512x640 8 cars, 3 trucks, 3 traffic lights, 736.4ms
# Speed: 7.0ms preprocess, 736.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0140_roi085.jpg
# Saved accident ROI: F:\output\accident\accident_frame0140_roi086.jpg
#
# 0: 512x640 11 cars, 2 trucks, 3 traffic lights, 659.3ms
# Speed: 4.0ms preprocess, 659.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0144_roi087.jpg
# Saved accident ROI: F:\output\accident\accident_frame0144_roi088.jpg
# Saved accident ROI: F:\output\accident\accident_frame0144_roi089.jpg
#
# 0: 512x640 11 cars, 2 trucks, 3 traffic lights, 523.8ms
# Speed: 3.0ms preprocess, 523.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0148_roi090.jpg
# Saved accident ROI: F:\output\accident\accident_frame0148_roi091.jpg
# Saved accident ROI: F:\output\accident\accident_frame0148_roi092.jpg
#
# 0: 512x640 12 cars, 2 trucks, 2 traffic lights, 521.1ms
# Speed: 3.0ms preprocess, 521.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0152_roi093.jpg
# Saved accident ROI: F:\output\accident\accident_frame0152_roi094.jpg
# Saved accident ROI: F:\output\accident\accident_frame0152_roi095.jpg
#
# 0: 512x640 10 cars, 2 trucks, 3 traffic lights, 526.3ms
# Speed: 3.0ms preprocess, 526.3ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0156_roi096.jpg
# Saved accident ROI: F:\output\accident\accident_frame0156_roi097.jpg
# Saved accident ROI: F:\output\accident\accident_frame0156_roi098.jpg
#
# 0: 512x640 10 cars, 2 trucks, 3 traffic lights, 529.7ms
# Speed: 3.0ms preprocess, 529.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0160_roi099.jpg
# Saved accident ROI: F:\output\accident\accident_frame0160_roi100.jpg
#
# 0: 512x640 9 cars, 3 trucks, 3 traffic lights, 524.5ms
# Speed: 3.0ms preprocess, 524.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0164_roi101.jpg
# Saved accident ROI: F:\output\accident\accident_frame0164_roi102.jpg
#
# 0: 512x640 10 cars, 3 trucks, 3 traffic lights, 528.7ms
# Speed: 3.0ms preprocess, 528.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0168_roi103.jpg
# Saved accident ROI: F:\output\accident\accident_frame0168_roi104.jpg
#
# 0: 512x640 10 cars, 2 trucks, 3 traffic lights, 516.8ms
# Speed: 3.0ms preprocess, 516.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0172_roi105.jpg
# Saved accident ROI: F:\output\accident\accident_frame0172_roi106.jpg
# Saved accident ROI: F:\output\accident\accident_frame0172_roi107.jpg
#
# 0: 512x640 8 cars, 4 trucks, 3 traffic lights, 450.8ms
# Speed: 3.0ms preprocess, 450.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0176_roi108.jpg
# Saved accident ROI: F:\output\accident\accident_frame0176_roi109.jpg
#
# 0: 512x640 8 cars, 3 trucks, 3 traffic lights, 484.3ms
# Speed: 3.0ms preprocess, 484.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0180_roi110.jpg
# Saved accident ROI: F:\output\accident\accident_frame0180_roi111.jpg
#
# 0: 512x640 8 cars, 3 trucks, 2 traffic lights, 472.2ms
# Speed: 3.0ms preprocess, 472.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0184_roi112.jpg
#
# 0: 512x640 8 cars, 3 trucks, 2 traffic lights, 459.8ms
# Speed: 3.0ms preprocess, 459.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0188_roi113.jpg
#
# 0: 512x640 8 cars, 3 trucks, 2 traffic lights, 494.7ms
# Speed: 3.1ms preprocess, 494.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0192_roi114.jpg
# Saved accident ROI: F:\output\accident\accident_frame0192_roi115.jpg
#
# 0: 512x640 9 cars, 3 trucks, 2 traffic lights, 476.3ms
# Speed: 3.0ms preprocess, 476.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0196_roi116.jpg
# Saved accident ROI: F:\output\accident\accident_frame0196_roi117.jpg
# Saved accident ROI: F:\output\accident\accident_frame0196_roi118.jpg
#
# 0: 512x640 8 cars, 2 trucks, 3 traffic lights, 470.0ms
# Speed: 2.0ms preprocess, 470.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0200_roi119.jpg
# Saved accident ROI: F:\output\accident\accident_frame0200_roi120.jpg
#
# 0: 512x640 8 cars, 3 trucks, 4 traffic lights, 468.1ms
# Speed: 3.0ms preprocess, 468.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0204_roi121.jpg
# Saved accident ROI: F:\output\accident\accident_frame0204_roi122.jpg
#
# 0: 512x640 8 cars, 4 trucks, 2 traffic lights, 482.0ms
# Speed: 4.0ms preprocess, 482.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0208_roi123.jpg
# Saved accident ROI: F:\output\accident\accident_frame0208_roi124.jpg
#
# 0: 512x640 9 cars, 2 trucks, 2 traffic lights, 681.5ms
# Speed: 5.0ms preprocess, 681.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0212_roi125.jpg
# Saved accident ROI: F:\output\accident\accident_frame0212_roi126.jpg
#
# 0: 512x640 7 cars, 2 trucks, 5 traffic lights, 637.6ms
# Speed: 4.0ms preprocess, 637.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0216_roi127.jpg
# Saved accident ROI: F:\output\accident\accident_frame0216_roi128.jpg
#
# 0: 512x640 8 cars, 3 trucks, 4 traffic lights, 518.6ms
# Speed: 3.0ms preprocess, 518.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0220_roi129.jpg
# Saved accident ROI: F:\output\accident\accident_frame0220_roi130.jpg
#
# 0: 512x640 8 cars, 3 trucks, 3 traffic lights, 538.8ms
# Speed: 3.0ms preprocess, 538.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0224_roi131.jpg
# Saved accident ROI: F:\output\accident\accident_frame0224_roi132.jpg
#
# 0: 512x640 6 cars, 3 trucks, 4 traffic lights, 527.6ms
# Speed: 3.0ms preprocess, 527.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0228_roi133.jpg
# Saved accident ROI: F:\output\accident\accident_frame0228_roi134.jpg
#
# 0: 512x640 7 cars, 3 trucks, 4 traffic lights, 521.5ms
# Speed: 6.0ms preprocess, 521.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0232_roi135.jpg
# Saved accident ROI: F:\output\accident\accident_frame0232_roi136.jpg
#
# 0: 512x640 7 cars, 3 trucks, 4 traffic lights, 567.4ms
# Speed: 5.0ms preprocess, 567.4ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame
jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0132_roi129.jpg
#
# 0: 384x640 16 cars, 2 trucks, 371.6ms
# Speed: 2.0ms preprocess, 371.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0136_roi130.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0136_roi131.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0136_roi132.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0136_roi133.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0136_roi134.jpg
#
# 0: 384x640 16 cars, 3 trucks, 535.4ms
# Speed: 3.0ms preprocess, 535.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0140_roi135.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0140_roi136.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0140_roi137.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0140_roi138.jpg
#
# 0: 384x640 17 cars, 4 trucks, 374.9ms
# Speed: 2.7ms preprocess, 374.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0144_roi139.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0144_roi140.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0144_roi141.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0144_roi142.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0144_roi143.jpg
#
# 0: 384x640 17 cars, 4 trucks, 393.4ms
# Speed: 2.0ms preprocess, 393.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0148_roi144.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0148_roi145.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0148_roi146.jpg
#
# 0: 384x640 1 person, 20 cars, 2 trucks, 392.4ms
# Speed: 2.0ms preprocess, 392.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi147.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi148.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi149.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi150.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi151.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi152.jpg
#
# 0: 384x640 18 cars, 4 trucks, 378.8ms
# Speed: 2.0ms preprocess, 378.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0156_roi153.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0156_roi154.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0156_roi155.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0156_roi156.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0156_roi157.jpg
#
# 0: 384x640 20 cars, 2 trucks, 371.7ms
# Speed: 2.0ms preprocess, 371.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0160_roi158.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0160_roi159.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0160_roi160.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0160_roi161.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0160_roi162.jpg
#
# 0: 384x640 1 person, 19 cars, 3 trucks, 376.6ms
# Speed: 2.0ms preprocess, 376.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi163.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi164.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi165.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi166.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi167.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi168.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi169.jpg
# Finished processing video: F:\pratice_dataset\pratice_nono_accident_video\negative_samples_151.mp4

# %%
import os
import math
import cv2
from ultralytics import YOLO

# Directories
ACCIDENT_VIDEOS_DIR = r"F:\pratice_dataset\practise_accident_video"
NONACCIDENT_VIDEOS_DIR = r"F:\pratice_dataset\pratice_nono_accident_video"
OUTPUT_DATASET_DIR = r"F:\output"
ACCIDENT_OUTPUT_DIR = os.path.join(OUTPUT_DATASET_DIR, 'accident')
NONACCIDENT_OUTPUT_DIR = os.path.join(OUTPUT_DATASET_DIR, 'nonaccident')
os.makedirs(ACCIDENT_OUTPUT_DIR, exist_ok=True)
os.makedirs(NONACCIDENT_OUTPUT_DIR, exist_ok=True)

# Frame skipping
FRAME_SKIP = 4

# Load YOLO model and define vehicle classes
yolo_model = YOLO("yolov5l.pt")
vehicle_classes = ["car", "truck", "bus", "motorcycle"]


def are_boxes_close(box1, box2, image_width, image_height, rel_distance_threshold=0.05):
    x1, y1, x2, y2 = box1
    xb1, yb1, xb2, yb2 = box2
    # overlap
    if x1 < xb2 and x2 > xb1 and y1 < yb2 and y2 > yb1:
        return True, 0
    # center distance
    c1 = ((x1+x2)/2, (y1+y2)/2)
    c2 = ((xb1+xb2)/2, (yb1+yb2)/2)
    dist = math.hypot(c1[0]-c2[0], c1[1]-c2[1])
    w1, h1 = x2-x1, y2-y1
    w2, h2 = xb2-xb1, yb2-yb1
    avg = (w1+h1+w2+h2)/4
    norm = dist/avg if avg>0 else float('inf')
    return norm < 2.0, norm


def combine_boxes(boxes, padding=0.1):
    x1 = min(b[0] for b in boxes)
    y1 = min(b[1] for b in boxes)
    x2 = max(b[2] for b in boxes)
    y2 = max(b[3] for b in boxes)
    w, h = x2-x1, y2-y1
    pad_x, pad_y = int(w*padding), int(h*padding)
    return (
        max(0, x1-pad_x),
        max(0, y1-pad_y),
        x2+pad_x,
        y2+pad_y
    )


def expand_roi_to_square(x1, y1, x2, y2, img_w, img_h):
    w = x2 - x1
    h = y2 - y1
    if w > h:
        diff = w - h
        y1n = max(0, y1 - diff//2)
        y2n = y2 + diff - (y1 - y1n)
        if y2n > img_h:
            y2n = img_h
            y1n = max(0, y2n - w)
        x1n, x2n = x1, x2
    elif h > w:
        diff = h - w
        x1n = max(0, x1 - diff//2)
        x2n = x2 + diff - (x1 - x1n)
        if x2n > img_w:
            x2n = img_w
            x1n = max(0, x2n - h)
        y1n, y2n = y1, y2
    else:
        x1n, y1n, x2n, y2n = x1, y1, x2, y2
    return x1n, y1n, x2n, y2n


def get_roi_patch(frame, x1, y1, x2, y2, output_size=224):
    img_h, img_w = frame.shape[:2]
    roi_w, roi_h = x2-x1, y2-y1
    # Large ROI: make square then resize
    if roi_w >= output_size and roi_h >= output_size:
        sx1, sy1, sx2, sy2 = expand_roi_to_square(x1, y1, x2, y2, img_w, img_h)
        patch = frame[sy1:sy2, sx1:sx2]
        patch = cv2.resize(patch, (output_size, output_size))
    else:
        # Small ROI: centered patch of fixed size
        cx = int((x1 + x2)/2)
        cy = int((y1 + y2)/2)
        half = output_size // 2
        nx1 = cx - half
        ny1 = cy - half
        nx2 = nx1 + output_size
        ny2 = ny1 + output_size
        # clamp
        if nx1 < 0:
            nx1, nx2 = 0, output_size
        if ny1 < 0:
            ny1, ny2 = 0, output_size
        if nx2 > img_w:
            nx2, nx1 = img_w, img_w - output_size
        if ny2 > img_h:
            ny2, ny1 = img_h, img_h - output_size
        patch = frame[ny1:ny2, nx1:nx2]
    return patch


def process_video(video_path, output_folder, label):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Could not open video: {video_path}")
        return
    fc = 0
    rc = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        fc += 1
        if fc % FRAME_SKIP != 0:
            continue
        h, w = frame.shape[:2]
        results = yolo_model(frame)
        boxes = []
        for r in results:
            for b in r.boxes:
                cls = int(b.cls[0]); conf = float(b.conf[0])
                name = yolo_model.names[cls]
                x1, y1, x2, y2 = map(int, b.xyxy[0])
                if name in vehicle_classes and conf > 0.5:
                    boxes.append((x1, y1, x2, y2))
        processed = set(); rois = []
        for i, b1 in enumerate(boxes):
            if i in processed: continue
            group = [b1]; processed.add(i)
            for j, b2 in enumerate(boxes[i+1:], start=i+1):
                if j in processed: continue
                close, _ = are_boxes_close(b1, b2, w, h)
                if close:
                    group.append(b2); processed.add(j)
            if len(group) > 1:
                rois.append(combine_boxes(group, padding=0.15))
        for roi in rois:
            x1, y1, x2, y2 = roi
            patch = get_roi_patch(frame, x1, y1, x2, y2)
            rc += 1
            out = os.path.join(output_folder, f"{label}_frame{fc:04d}_roi{rc:03d}.jpg")
            cv2.imwrite(out, patch)
            print(f"Saved {label} ROI: {out}")
    cap.release()
    print(f"Finished: {video_path}")

# Start processing
process_video_paths = [
    (ACCIDENT_VIDEOS_DIR, ACCIDENT_OUTPUT_DIR, 'accident'),
    (NONACCIDENT_VIDEOS_DIR, NONACCIDENT_OUTPUT_DIR, 'nonaccident')
]
for inp, outp, lbl in process_video_paths:
    for fn in os.listdir(inp):
        if fn.lower().endswith(('.mp4', '.avi', '.mov')):
            process_video(os.path.join(inp, fn), outp, lbl)
# Out:
# PRO TIP  Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
#
# 0: 512x640 8 cars, 2 trucks, 5 traffic lights, 484.9ms
# Speed: 4.0ms preprocess, 484.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0004_roi001.jpg
# Saved accident ROI: F:\output\accident\accident_frame0004_roi002.jpg
# Saved accident ROI: F:\output\accident\accident_frame0004_roi003.jpg
#
# 0: 512x640 7 cars, 2 trucks, 5 traffic lights, 475.3ms
# Speed: 3.0ms preprocess, 475.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0008_roi004.jpg
# Saved accident ROI: F:\output\accident\accident_frame0008_roi005.jpg
# Saved accident ROI: F:\output\accident\accident_frame0008_roi006.jpg
#
# 0: 512x640 7 cars, 2 trucks, 5 traffic lights, 474.9ms
# Speed: 3.0ms preprocess, 474.9ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0012_roi007.jpg
# Saved accident ROI: F:\output\accident\accident_frame0012_roi008.jpg
# Saved accident ROI: F:\output\accident\accident_frame0012_roi009.jpg
#
# 0: 512x640 9 cars, 1 truck, 5 traffic lights, 474.6ms
# Speed: 3.0ms preprocess, 474.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0016_roi010.jpg
# Saved accident ROI: F:\output\accident\accident_frame0016_roi011.jpg
#
# 0: 512x640 8 cars, 1 truck, 4 traffic lights, 478.0ms
# Speed: 3.0ms preprocess, 478.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0020_roi012.jpg
# Saved accident ROI: F:\output\accident\accident_frame0020_roi013.jpg
# Saved accident ROI: F:\output\accident\accident_frame0020_roi014.jpg
#
# 0: 512x640 10 cars, 1 truck, 4 traffic lights, 492.0ms
# Speed: 3.0ms preprocess, 492.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0024_roi015.jpg
# Saved accident ROI: F:\output\accident\accident_frame0024_roi016.jpg
# Saved accident ROI: F:\output\accident\accident_frame0024_roi017.jpg
#
# 0: 512x640 8 cars, 1 truck, 4 traffic lights, 474.8ms
# Speed: 3.0ms preprocess, 474.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0028_roi018.jpg
# Saved accident ROI: F:\output\accident\accident_frame0028_roi019.jpg
#
# 0: 512x640 9 cars, 1 truck, 4 traffic lights, 476.8ms
# Speed: 2.0ms preprocess, 476.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0032_roi020.jpg
# Saved accident ROI: F:\output\accident\accident_frame0032_roi021.jpg
#
# 0: 512x640 9 cars, 1 truck, 4 traffic lights, 479.0ms
# Speed: 2.0ms preprocess, 479.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0036_roi022.jpg
# Saved accident ROI: F:\output\accident\accident_frame0036_roi023.jpg
#
# 0: 512x640 7 cars, 2 trucks, 4 traffic lights, 482.4ms
# Speed: 2.0ms preprocess, 482.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0040_roi024.jpg
# Saved accident ROI: F:\output\accident\accident_frame0040_roi025.jpg
#
# 0: 512x640 8 cars, 1 truck, 4 traffic lights, 470.6ms
# Speed: 3.0ms preprocess, 470.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0044_roi026.jpg
# Saved accident ROI: F:\output\accident\accident_frame0044_roi027.jpg
# Saved accident ROI: F:\output\accident\accident_frame0044_roi028.jpg
#
# 0: 512x640 7 cars, 1 bus, 1 truck, 4 traffic lights, 466.9ms
# Speed: 3.0ms preprocess, 466.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0048_roi029.jpg
# Saved accident ROI: F:\output\accident\accident_frame0048_roi030.jpg
# Saved accident ROI: F:\output\accident\accident_frame0048_roi031.jpg
#
# 0: 512x640 10 cars, 1 bus, 1 truck, 4 traffic lights, 490.7ms
# Speed: 2.0ms preprocess, 490.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0052_roi032.jpg
# Saved accident ROI: F:\output\accident\accident_frame0052_roi033.jpg
# Saved accident ROI: F:\output\accident\accident_frame0052_roi034.jpg
#
# 0: 512x640 9 cars, 1 bus, 1 truck, 4 traffic lights, 487.8ms
# Speed: 2.0ms preprocess, 487.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0056_roi035.jpg
# Saved accident ROI: F:\output\accident\accident_frame0056_roi036.jpg
# Saved accident ROI: F:\output\accident\accident_frame0056_roi037.jpg
# Saved accident ROI: F:\output\accident\accident_frame0056_roi038.jpg
#
# 0: 512x640 10 cars, 1 bus, 2 traffic lights, 483.7ms
# Speed: 3.0ms preprocess, 483.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0060_roi039.jpg
# Saved accident ROI: F:\output\accident\accident_frame0060_roi040.jpg
# Saved accident ROI: F:\output\accident\accident_frame0060_roi041.jpg
# Saved accident ROI: F:\output\accident\accident_frame0060_roi042.jpg
#
# 0: 512x640 9 cars, 1 truck, 4 traffic lights, 536.2ms
# Speed: 3.2ms preprocess, 536.2ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0064_roi043.jpg
# Saved accident ROI: F:\output\accident\accident_frame0064_roi044.jpg
# Saved accident ROI: F:\output\accident\accident_frame0064_roi045.jpg
# Saved accident ROI: F:\output\accident\accident_frame0064_roi046.jpg
#
# 0: 512x640 10 cars, 1 truck, 5 traffic lights, 636.6ms
# Speed: 4.0ms preprocess, 636.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0068_roi047.jpg
# Saved accident ROI: F:\output\accident\accident_frame0068_roi048.jpg
# Saved accident ROI: F:\output\accident\accident_frame0068_roi049.jpg
# Saved accident ROI: F:\output\accident\accident_frame0068_roi050.jpg
#
# 0: 512x640 9 cars, 1 bus, 1 truck, 4 traffic lights, 539.7ms
# Speed: 3.0ms preprocess, 539.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0072_roi051.jpg
# Saved accident ROI: F:\output\accident\accident_frame0072_roi052.jpg
#
# 0: 512x640 8 cars, 1 bus, 2 trucks, 4 traffic lights, 510.1ms
# Speed: 3.0ms preprocess, 510.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0076_roi053.jpg
# Saved accident ROI: F:\output\accident\accident_frame0076_roi054.jpg
#
# 0: 512x640 10 cars, 2 trucks, 4 traffic lights, 492.8ms
# Speed: 3.0ms preprocess, 492.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0080_roi055.jpg
# Saved accident ROI: F:\output\accident\accident_frame0080_roi056.jpg
#
# 0: 512x640 10 cars, 2 trucks, 4 traffic lights, 475.8ms
# Speed: 3.0ms preprocess, 475.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0084_roi057.jpg
# Saved accident ROI: F:\output\accident\accident_frame0084_roi058.jpg
#
# 0: 512x640 10 cars, 1 truck, 4 traffic lights, 486.0ms
# Speed: 2.0ms preprocess, 486.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0088_roi059.jpg
# Saved accident ROI: F:\output\accident\accident_frame0088_roi060.jpg
#
# 0: 512x640 10 cars, 1 bus, 3 trucks, 4 traffic lights, 480.1ms
# Speed: 2.0ms preprocess, 480.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0092_roi061.jpg
# Saved accident ROI: F:\output\accident\accident_frame0092_roi062.jpg
#
# 0: 512x640 10 cars, 3 trucks, 3 traffic lights, 486.7ms
# Speed: 3.0ms preprocess, 486.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0096_roi063.jpg
# Saved accident ROI: F:\output\accident\accident_frame0096_roi064.jpg
#
# 0: 512x640 9 cars, 3 trucks, 2 traffic lights, 488.2ms
# Speed: 3.0ms preprocess, 488.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0100_roi065.jpg
# Saved accident ROI: F:\output\accident\accident_frame0100_roi066.jpg
#
# 0: 512x640 12 cars, 4 trucks, 2 traffic lights, 479.0ms
# Speed: 2.0ms preprocess, 479.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0104_roi067.jpg
# Saved accident ROI: F:\output\accident\accident_frame0104_roi068.jpg
#
# 0: 512x640 11 cars, 3 trucks, 2 traffic lights, 474.9ms
# Speed: 3.0ms preprocess, 474.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0108_roi069.jpg
# Saved accident ROI: F:\output\accident\accident_frame0108_roi070.jpg
#
# 0: 512x640 11 cars, 4 trucks, 2 traffic lights, 481.9ms
# Speed: 2.0ms preprocess, 481.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0112_roi071.jpg
# Saved accident ROI: F:\output\accident\accident_frame0112_roi072.jpg
#
# 0: 512x640 11 cars, 3 trucks, 2 traffic lights, 480.2ms
# Speed: 3.0ms preprocess, 480.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0116_roi073.jpg
# Saved accident ROI: F:\output\accident\accident_frame0116_roi074.jpg
#
# 0: 512x640 11 cars, 2 trucks, 4 traffic lights, 478.8ms
# Speed: 3.0ms preprocess, 478.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0120_roi075.jpg
# Saved accident ROI: F:\output\accident\accident_frame0120_roi076.jpg
#
# 0: 512x640 9 cars, 4 trucks, 3 traffic lights, 477.8ms
# Speed: 2.0ms preprocess, 477.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0124_roi077.jpg
# Saved accident ROI: F:\output\accident\accident_frame0124_roi078.jpg
#
# 0: 512x640 10 cars, 2 trucks, 3 traffic lights, 487.1ms
# Speed: 2.0ms preprocess, 487.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0128_roi079.jpg
# Saved accident ROI: F:\output\accident\accident_frame0128_roi080.jpg
#
# 0: 512x640 6 cars, 2 trucks, 3 traffic lights, 484.8ms
# Speed: 3.0ms preprocess, 484.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0132_roi081.jpg
# Saved accident ROI: F:\output\accident\accident_frame0132_roi082.jpg
#
# 0: 512x640 9 cars, 2 trucks, 3 traffic lights, 484.3ms
# Speed: 3.0ms preprocess, 484.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0136_roi083.jpg
# Saved accident ROI: F:\output\accident\accident_frame0136_roi084.jpg
#
# 0: 512x640 8 cars, 3 trucks, 3 traffic lights, 481.9ms
# Speed: 3.0ms preprocess, 481.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0140_roi085.jpg
# Saved accident ROI: F:\output\accident\accident_frame0140_roi086.jpg
#
# 0: 512x640 11 cars, 2 trucks, 3 traffic lights, 484.8ms
# Speed: 2.0ms preprocess, 484.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0144_roi087.jpg
# Saved accident ROI: F:\output\accident\accident_frame0144_roi088.jpg
# Saved accident ROI: F:\output\accident\accident_frame0144_roi089.jpg
#
# 0: 512x640 11 cars, 2 trucks, 3 traffic lights, 492.6ms
# Speed: 2.0ms preprocess, 492.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0148_roi090.jpg
# Saved accident ROI: F:\output\accident\accident_frame0148_roi091.jpg
# Saved accident ROI: F:\output\accident\accident_frame0148_roi092.jpg
#
# 0: 512x640 12 cars, 2 trucks, 2 traffic lights, 483.9ms
# Speed: 2.0ms preprocess, 483.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0152_roi093.jpg
# Saved accident ROI: F:\output\accident\accident_frame0152_roi094.jpg
# Saved accident ROI: F:\output\accident\accident_frame0152_roi095.jpg
#
# 0: 512x640 10 cars, 2 trucks, 3 traffic lights, 477.8ms
# Speed: 3.0ms preprocess, 477.8ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0156_roi096.jpg
# Saved accident ROI: F:\output\accident\accident_frame0156_roi097.jpg
# Saved accident ROI: F:\output\accident\accident_frame0156_roi098.jpg
#
# 0: 512x640 10 cars, 2 trucks, 3 traffic lights, 491.2ms
# Speed: 2.0ms preprocess, 491.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0160_roi099.jpg
# Saved accident ROI: F:\output\accident\accident_frame0160_roi100.jpg
#
# 0: 512x640 9 cars, 3 trucks, 3 traffic lights, 482.8ms
# Speed: 3.0ms preprocess, 482.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0164_roi101.jpg
# Saved accident ROI: F:\output\accident\accident_frame0164_roi102.jpg
#
# 0: 512x640 10 cars, 3 trucks, 3 traffic lights, 482.9ms
# Speed: 3.0ms preprocess, 482.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0168_roi103.jpg
# Saved accident ROI: F:\output\accident\accident_frame0168_roi104.jpg
#
# 0: 512x640 10 cars, 2 trucks, 3 traffic lights, 479.6ms
# Speed: 3.0ms preprocess, 479.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0172_roi105.jpg
# Saved accident ROI: F:\output\accident\accident_frame0172_roi106.jpg
# Saved accident ROI: F:\output\accident\accident_frame0172_roi107.jpg
#
# 0: 512x640 8 cars, 4 trucks, 3 traffic lights, 496.0ms
# Speed: 2.0ms preprocess, 496.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0176_roi108.jpg
# Saved accident ROI: F:\output\accident\accident_frame0176_roi109.jpg
#
# 0: 512x640 8 cars, 3 trucks, 3 traffic lights, 489.9ms
# Speed: 2.0ms preprocess, 489.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0180_roi110.jpg
# Saved accident ROI: F:\output\accident\accident_frame0180_roi111.jpg
#
# 0: 512x640 8 cars, 3 trucks, 2 traffic lights, 491.9ms
# Speed: 2.0ms preprocess, 491.9ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0184_roi112.jpg
#
# 0: 512x640 8 cars, 3 trucks, 2 traffic lights, 499.0ms
# Speed: 3.0ms preprocess, 499.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0188_roi113.jpg
#
# 0: 512x640 8 cars, 3 trucks, 2 traffic lights, 507.0ms
# Speed: 3.5ms preprocess, 507.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0192_roi114.jpg
# Saved accident ROI: F:\output\accident\accident_frame0192_roi115.jpg
#
# 0: 512x640 9 cars, 3 trucks, 2 traffic lights, 483.0ms
# Speed: 2.0ms preprocess, 483.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0196_roi116.jpg
# Saved accident ROI: F:\output\accident\accident_frame0196_roi117.jpg
# Saved accident ROI: F:\output\accident\accident_frame0196_roi118.jpg
#
# 0: 512x640 8 cars, 2 trucks, 3 traffic lights, 483.6ms
# Speed: 3.0ms preprocess, 483.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0200_roi119.jpg
# Saved accident ROI: F:\output\accident\accident_frame0200_roi120.jpg
#
# 0: 512x640 8 cars, 3 trucks, 4 traffic lights, 485.8ms
# Speed: 2.0ms preprocess, 485.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0204_roi121.jpg
# Saved accident ROI: F:\output\accident\accident_frame0204_roi122.jpg
#
# 0: 512x640 8 cars, 4 trucks, 2 traffic lights, 489.0ms
# Speed: 3.0ms preprocess, 489.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0208_roi123.jpg
# Saved accident ROI: F:\output\accident\accident_frame0208_roi124.jpg
#
# 0: 512x640 9 cars, 2 trucks, 2 traffic lights, 509.0ms
# Speed: 3.0ms preprocess, 509.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0212_roi125.jpg
# Saved accident ROI: F:\output\accident\accident_frame0212_roi126.jpg
#
# 0: 512x640 7 cars, 2 trucks, 5 traffic lights, 494.8ms
# Speed: 2.0ms preprocess, 494.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0216_roi127.jpg
# Saved accident ROI: F:\output\accident\accident_frame0216_roi128.jpg
#
# 0: 512x640 8 cars, 3 trucks, 4 traffic lights, 480.7ms
# Speed: 3.0ms preprocess, 480.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0220_roi129.jpg
# Saved accident ROI: F:\output\accident\accident_frame0220_roi130.jpg
#
# 0: 512x640 8 cars, 3 trucks, 3 traffic lights, 484.5ms
# Speed: 3.0ms preprocess, 484.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0224_roi131.jpg
# Saved accident ROI: F:\output\accident\accident_frame0224_roi132.jpg
#
# 0: 512x640 6 cars, 3 trucks, 4 traffic lights, 474.7ms
# Speed: 2.0ms preprocess, 474.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0228_roi133.jpg
# Saved accident ROI: F:\output\accident\accident_frame0228_roi134.jpg
#
# 0: 512x640 7 cars, 3 trucks, 4 traffic lights, 488.3ms
# Speed: 2.0ms preprocess, 488.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0232_roi135.jpg
# Saved accident ROI: F:\output\accident\accident_frame0232_roi136.jpg
#
# 0: 512x640 7 cars, 3 trucks, 4 traffic lights, 476.2ms
# Speed: 3.0ms preprocess, 476.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0236_roi137.jpg
# Saved accident ROI: F:\output\accident\accident_frame0236_roi138.jpg
#
# 0: 512x640 7 cars, 3 trucks, 3 traffic lights, 488.7ms
# Speed: 2.0ms preprocess, 488.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0240_roi139.jpg
#
# 0: 512x640 7 cars, 3 trucks, 4 traffic lights, 470.7ms
# Speed: 2.0ms preprocess, 470.7ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0244_roi140.jpg
# Saved accident ROI: F:\output\accident\accident_frame0244_roi141.jpg
#
# 0: 512x640 7 cars, 3 trucks, 4 traffic lights, 468.3ms
# Speed: 2.0ms preprocess, 468.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0248_roi142.jpg
# Saved accident ROI: F:\output\accident\accident_frame0248_roi143.jpg
#
# 0: 512x640 7 cars, 3 trucks, 4 traffic lights, 472.7ms
# Speed: 3.0ms preprocess, 472.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0252_roi144.jpg
# Saved accident ROI: F:\output\accident\accident_frame0252_roi145.jpg
#
# 0: 512x640 7 cars, 3 trucks, 3 traffic lights, 463.6ms
# Speed: 2.0ms preprocess, 463.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0256_roi146.jpg
#
# 0: 512x640 7 cars, 3 trucks, 4 traffic lights, 476.5ms
# Speed: 3.0ms preprocess, 476.5ms inference, 3.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0260_roi147.jpg
#
# 0: 512x640 7 cars, 3 trucks, 3 traffic lights, 478.7ms
# Speed: 3.0ms preprocess, 478.7ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0264_roi148.jpg
# Saved accident ROI: F:\output\accident\accident_frame0264_roi149.jpg
#
# 0: 512x640 7 cars, 3 trucks, 4 traffic lights, 504.8ms
# Speed: 2.0ms preprocess, 504.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0268_roi150.jpg
# Saved accident ROI: F:\output\accident\accident_frame0268_roi151.jpg
#
# 0: 512x640 7 cars, 3 trucks, 4 traffic lights, 492.6ms
# Speed: 3.0ms preprocess, 492.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0272_roi152.jpg
#
# 0: 512x640 8 cars, 3 trucks, 4 traffic lights, 481.4ms
# Speed: 3.0ms preprocess, 481.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Saved accident ROI: F:\output\accident\accident_frame0276_roi153.jpg
# Finished: F:\pratice_dataset\practise_accident_video\video045.mp4
#
# 0: 384x640 1 person, 16 cars, 2 trucks, 359.7ms
# Speed: 2.0ms preprocess, 359.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0004_roi001.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0004_roi002.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0004_roi003.jpg
#
# 0: 384x640 1 person, 16 cars, 2 trucks, 373.0ms
# Speed: 1.0ms preprocess, 373.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0008_ro
jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0088_roi082.jpg
#
# 0: 384x640 3 persons, 19 cars, 3 trucks, 377.9ms
# Speed: 2.0ms preprocess, 377.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0092_roi083.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0092_roi084.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0092_roi085.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0092_roi086.jpg
#
# 0: 384x640 3 persons, 17 cars, 4 trucks, 383.9ms
# Speed: 1.0ms preprocess, 383.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0096_roi087.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0096_roi088.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0096_roi089.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0096_roi090.jpg
#
# 0: 384x640 2 persons, 17 cars, 4 trucks, 368.6ms
# Speed: 2.0ms preprocess, 368.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0100_roi091.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0100_roi092.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0100_roi093.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0100_roi094.jpg
#
# 0: 384x640 19 cars, 4 trucks, 372.3ms
# Speed: 2.0ms preprocess, 372.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0104_roi095.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0104_roi096.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0104_roi097.jpg
#
# 0: 384x640 18 cars, 3 trucks, 375.2ms
# Speed: 1.0ms preprocess, 375.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0108_roi098.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0108_roi099.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0108_roi100.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0108_roi101.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0108_roi102.jpg
#
# 0: 384x640 14 cars, 4 trucks, 380.7ms
# Speed: 2.0ms preprocess, 380.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0112_roi103.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0112_roi104.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0112_roi105.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0112_roi106.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0112_roi107.jpg
#
# 0: 384x640 14 cars, 4 trucks, 377.7ms
# Speed: 1.0ms preprocess, 377.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0116_roi108.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0116_roi109.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0116_roi110.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0116_roi111.jpg
#
# 0: 384x640 16 cars, 3 trucks, 375.3ms
# Speed: 2.0ms preprocess, 375.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0120_roi112.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0120_roi113.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0120_roi114.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0120_roi115.jpg
#
# 0: 384x640 14 cars, 2 trucks, 375.2ms
# Speed: 2.0ms preprocess, 375.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0124_roi116.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0124_roi117.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0124_roi118.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0124_roi119.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0124_roi120.jpg
#
# 0: 384x640 14 cars, 4 trucks, 395.2ms
# Speed: 1.0ms preprocess, 395.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0128_roi121.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0128_roi122.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0128_roi123.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0128_roi124.jpg
#
# 0: 384x640 16 cars, 4 trucks, 376.6ms
# Speed: 1.0ms preprocess, 376.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0132_roi125.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0132_roi126.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0132_roi127.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0132_roi128.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0132_roi129.jpg
#
# 0: 384x640 16 cars, 2 trucks, 377.2ms
# Speed: 2.0ms preprocess, 377.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0136_roi130.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0136_roi131.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0136_roi132.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0136_roi133.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0136_roi134.jpg
#
# 0: 384x640 16 cars, 3 trucks, 376.6ms
# Speed: 1.0ms preprocess, 376.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0140_roi135.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0140_roi136.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0140_roi137.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0140_roi138.jpg
#
# 0: 384x640 17 cars, 4 trucks, 382.4ms
# Speed: 2.0ms preprocess, 382.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0144_roi139.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0144_roi140.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0144_roi141.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0144_roi142.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0144_roi143.jpg
#
# 0: 384x640 17 cars, 4 trucks, 376.5ms
# Speed: 2.0ms preprocess, 376.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0148_roi144.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0148_roi145.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0148_roi146.jpg
#
# 0: 384x640 1 person, 20 cars, 2 trucks, 372.2ms
# Speed: 2.0ms preprocess, 372.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi147.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi148.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi149.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi150.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi151.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0152_roi152.jpg
#
# 0: 384x640 18 cars, 4 trucks, 375.7ms
# Speed: 2.0ms preprocess, 375.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0156_roi153.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0156_roi154.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0156_roi155.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0156_roi156.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0156_roi157.jpg
#
# 0: 384x640 20 cars, 2 trucks, 376.2ms
# Speed: 3.0ms preprocess, 376.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0160_roi158.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0160_roi159.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0160_roi160.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0160_roi161.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0160_roi162.jpg
#
# 0: 384x640 1 person, 19 cars, 3 trucks, 369.4ms
# Speed: 1.0ms preprocess, 369.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi163.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi164.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi165.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi166.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi167.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi168.jpg
# Saved nonaccident ROI: F:\output\nonaccident\nonaccident_frame0164_roi169.jpg
# Finished: F:\pratice_dataset\pratice_nono_accident_video\negative_samples_151.mp4
